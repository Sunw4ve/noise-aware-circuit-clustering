# %%
# %load_ext autoreload
# %autoreload 2

import networkx as nx
from networkx.algorithms import approximation
from src.clusterparser import ClusterParser
from src.small_world import generate_circuit_graph, avg_path_length, avg_clustering_icn, noise_cell_proportion, remove_ICN_experiment
from src.rents_rule import RentsRuleCalculator
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### 1 Clustering

# %%
DESIGN = "aes"
isDefLef = False

if isDefLef:
    node_file = f"./test/{DESIGN}/cells.lef"
    net_file = f"./test/{DESIGN}/floorplan.def"
else:
    node_file = f"./test/{DESIGN}/{DESIGN}.nodes"
    net_file = f"./test/{DESIGN}/{DESIGN}.nets"

cp = ClusterParser(node_file, net_file, 100)
print(cp.num_std_cells, cp.num_macros, cp.num_terminals)
# Out:
# 15690 0 390

# %%
import os

prefix = f"./test/{DESIGN}/placement-positions/{DESIGN}.gp.pl-"

# iteration range for clustering: start at 200, step by 50, stop when file not found
its = []
i = 200
while os.path.exists(f"{prefix}{i}"):
    its.append(i)
    i += 50
position_files = [f"{prefix}{i}" for i in its]
cp.load_positions(position_files)
print(f"Loaded {len(its)} snapshots: {its[0]} to {its[-1]}")
# Out:
# Loaded 7 snapshots: 200 to 500

# %%
require_clustering = True
plot = True
cluster_file = f"./test/{DESIGN}/{DESIGN}.cluster.csv"
output_file = f"./test/{DESIGN}/{DESIGN}.cluster.txt"

msl = [800, 400, 200]
if require_clustering:
    cp.clustering(min_size_list=msl, min_samples=1, epsilon=0)
    cp.save_clustering(cluster_file, output_file)
else:
    cp.load_clustering(cluster_file)
print(f"Num cluster: {len(cp.unique_labels)}, Num cells: {len(cp.labels)}, Num intercells: {len(cp.noise_points)}, ICN%: {len(cp.noise_points)/len(cp.labels) * 100:.2f}%")
if plot:
    cp.plot_snapshot()
# Out:
# Num cluster: 16, Num cells: 16080, Num intercells: 638, ICN%: 3.97%

# %%
#from src.visualize import generate_html_visualization, generate_path_visualization
#generate_html_visualization(cp, DESIGN, f"./test/{DESIGN}/{DESIGN}_clustering.html")
#generate_path_visualization(cp, DESIGN, f"./test/{DESIGN}/{DESIGN}_path.html")

# %%
from src.visualize import generate_module_visualization
generate_module_visualization(
    cp, DESIGN,
    module_csv="./misc/cell_id_map.csv",
    output_html=f"./test/{DESIGN}/{DESIGN}_modules.html",
)
# Out:
# Saved to ./test/aes/aes_modules.html
#   1 groups: unknown
#   0/16080 cells labeled (0.0%)

# %%
from src.visualize import generate_cluster_module_visualization
generate_cluster_module_visualization(
    cp, DESIGN,
    module_csv="./misc/cell_id_map.csv",
    output_html=f"./test/{DESIGN}/{DESIGN}_cluster_modules.html",
)
# Out:
# Saved to ./test/aes/aes_cluster_modules.html
#   15 clusters + ICN | 1 module groups

# %%
# Plot noise (ICN) points only
cp.plot_snapshot(noise=True, labels=[-1])

# %%
# Plot clusters only (no noise/ICN)
cp.plot_snapshot(noise=False)

# %% [markdown]
# ### 2 Rent's Rule Analysis

# %%
rrc = RentsRuleCalculator(cp)

# %%
rrc.approximate()
# Out:
# Approximated Rent's exponent (block p): 0.85
# Approximated Rent's coefficient (block dk): 1.77
# Approximated Rent's exponent (cluster p): 0.45
# Approximated Rent's coefficient (cluster k): 4.92
# Approximated Rent's exponent (p): 0.72
# Approximated Rent's coefficient (k): 3.18

# %%
import numpy as np
intra_ps, intra_ks = rrc.intra_rents()
print(f"Avg Intra-Cluster Rent's exponent (p): {np.mean(intra_ps):.2f}")
print(f"Avg Intra-Cluster Rent's coefficient (k): {np.mean(intra_ks):.2f}")
# Out:
# Avg Intra-Cluster Rent's exponent (p): 0.71
# Avg Intra-Cluster Rent's coefficient (k): 4.02

# %% [markdown]
# ### 3 Small World Analysis

# %%
G = generate_circuit_graph(cp)

# %%
N = 5000
M = 1000000

n_nodes = len(G.nodes)
n_edges = len(G.edges)

L_actual = avg_path_length(G, N, cp.labels)
L_icn = avg_path_length(G, N, cp.labels, mode="icn")
L_cluster = avg_path_length(G, N, cp.labels, mode="cluster")

C_actural = approximation.average_clustering(G, trials=M, seed=42)
C_icn = avg_clustering_icn(G, M, cp.labels, True)
C_cluster = avg_clustering_icn(G, M, cp.labels, False)

G_random = nx.gnm_random_graph(n_nodes, n_edges, seed=42)
L_random, _ = avg_path_length(G_random, N, cp.labels)
C_random = approximation.average_clustering(G_random, trials=M, seed=42)

print(f"#nodes: {n_nodes:,}, #edges: {n_edges:,}")
print(f"L_netlist: {L_actual[0]:.4f}, L_random: {L_random:.4f}, L_cluster: {L_cluster[0]:.4f}, L_ICN: {L_icn[0]:.4f}")
print(f"C_netlist: {C_actural:.4f}, C_random: {C_random:.2e}, C_cluster: {C_cluster:.4f}, C_ICN: {C_icn:.4f}")
# Out:
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# #nodes: 16,078, #edges: 37,227
# L_netlist: 7.8090, L_random: 6.4762, L_cluster: 7.8786, L_ICN: 7.0525
# C_netlist: 0.0068, C_random: 3.08e-04, C_cluster: 0.0070, C_ICN: 0.0041

# %%
noise_prop = noise_cell_proportion(G, N, cp.labels)
print(f"Noise cell% on shortest path: {noise_prop[0] * 100:.2f}%")
# Out:
# Noise cell% on shortest path: 11.74%

# %%
remove_ICN_experiment(G, N, cp.labels)
# Out:
# L_remove_icn: 9.84, fail: 0/5000
# L_remove_contrast: 7.98, fail: 15/5000

# %%
def compute_hpwl(cp, exclude_icn=False):
    """Compute total HPWL (Half-Perimeter Wirelength).

    Args:
        cp: ClusterParser with loaded positions and clustering
        exclude_icn: if True, skip ICN cells (label == -1) from each net
    Returns:
        total HPWL (float)
    """
    # Final snapshot positions are the last 2 columns of cp.data (lower-left corner)
    final_x = cp.data[:, -2]
    final_y = cp.data[:, -1]
    num_cells = len(final_x)

    total_hpwl = 0.0
    for net in cp.net_nodes:
        xs, ys = [], []
        for node_id, x_off, y_off, _ in net:
            if node_id >= num_cells:
                continue
            if exclude_icn and cp.labels[node_id] == -1:
                continue
            # offsets in .nets are relative to cell center; add half-cell to get absolute pin pos
            cx = final_x[node_id] + cp.node_size_x[node_id] / 2.0 + x_off
            cy = final_y[node_id] + cp.node_size_y[node_id] / 2.0 + y_off
            xs.append(cx)
            ys.append(cy)
        if len(xs) < 3:
            continue
        total_hpwl += (max(xs) - min(xs)) + (max(ys) - min(ys))
    return total_hpwl

hpwl_with_icn = compute_hpwl(cp, exclude_icn=False)
hpwl_without_icn = compute_hpwl(cp, exclude_icn=True)

print(f"HPWL (with ICN):    {hpwl_with_icn:,.0f}")
print(f"HPWL (without ICN): {hpwl_without_icn:,.0f}")
print(f"HPWL reduction:     {(1 - hpwl_without_icn / hpwl_with_icn) * 100:.2f}%")
# Out:
# HPWL (with ICN):    592,086
# HPWL (without ICN): 582,917
# HPWL reduction:     1.55%

# %% [markdown]
# ### 5 Module Analysis

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import normalized_mutual_info_score

MODULE_CSV = "./misc/cell_id_map.csv"

# Build short_id -> module/group lookup
id_to_module = {}
id_to_group = {}
with open(MODULE_CSV, newline='') as f:
    for row in csv.DictReader(f):
        id_to_module[row['short_id']] = row['module']
        id_to_group[row['short_id']] = row['group']

# Assign module label to every node
node_modules = [id_to_module.get(cp.node_names[i], 'unknown') for i in range(len(cp.node_names))]
node_groups  = [id_to_group.get(cp.node_names[i],  'unknown') for i in range(len(cp.node_names))]
node_modules = np.array(node_modules)
node_groups  = np.array(node_groups)

# %%
# --- ICN cells per module ---
icn_mask = cp.labels == -1
icn_modules = node_modules[icn_mask]

icn_counts = pd.Series(icn_modules).value_counts().sort_index()
total_per_module = pd.Series(node_modules).value_counts().sort_index()
icn_pct = (icn_counts / total_per_module * 100).fillna(0).sort_values(ascending=False)

rows = []
for mod in icn_pct.index:
    rows.append([mod, int(icn_counts.get(mod, 0)), int(total_per_module.get(mod, 0)), f"{icn_pct[mod]:.1f}%"])

fig, ax = plt.subplots(figsize=(5, 0.3 * len(rows) + 0.3))
ax.axis('off')
tbl = ax.table(
    cellText=rows,
    colLabels=['Module', 'ICN', 'Total', 'ICN%'],
    cellLoc='center',
    loc='center',
    bbox=[0, 0, 1, 1],
)
tbl.auto_set_font_size(False)
tbl.set_fontsize(10)
tbl.auto_set_column_width([0, 1, 2, 3])
for (r, c), cell in tbl.get_celld().items():
    if r == 0:
        cell.set_facecolor('#333333')
        cell.set_text_props(color='white', fontweight='bold')
    elif r % 2 == 0:
        cell.set_facecolor('#f0f0f0')
    cell.set_edgecolor('#cccccc')
plt.subplots_adjust(left=0, right=1, top=1, bottom=0)
plt.show()

# %%
# --- Cluster × Module heatmap (with ICN column) ---
cluster_labels = sorted([l for l in np.unique(cp.labels) if l != -1])
modules_sorted = sorted(set(node_modules) - {'unknown'}) + (['unknown'] if 'unknown' in set(node_modules) else [])

# Columns: clusters + ICN
col_labels = cluster_labels + ['ICN']

matrix = np.zeros((len(modules_sorted), len(col_labels)), dtype=int)
for mi, mod in enumerate(modules_sorted):
    mod_mask = node_modules == mod
    for ci, cl in enumerate(cluster_labels):
        matrix[mi, ci] = np.sum((cp.labels == cl) & mod_mask)
    matrix[mi, -1] = np.sum((cp.labels == -1) & mod_mask)

# Normalize each row (per module) so values sum to 1
matrix_norm = matrix / (matrix.sum(axis=1, keepdims=True) + 1e-9)

fig, ax = plt.subplots(figsize=(max(8, len(col_labels) * 0.35), 5))
im = ax.imshow(matrix_norm, aspect='auto', cmap='Blues')
ax.set_yticks(range(len(modules_sorted)))
ax.set_yticklabels(modules_sorted, fontsize=9)
ax.set_xticks(range(len(col_labels)))
xticklabels = [f'C{l}' for l in cluster_labels] + ['ICN']
ax.set_xticklabels(xticklabels, rotation=45, ha='right', fontsize=8)
# Highlight the ICN column with a vertical line
ax.axvline(len(cluster_labels) - 0.5, color='red', linewidth=1.2, linestyle='--')
ax.set_ylabel('Module')
ax.set_xlabel('Cluster / ICN')
ax.set_title(f'{DESIGN} — Module × Cluster composition (row-normalized)')
plt.colorbar(im, ax=ax, label='Fraction of module cells')
plt.tight_layout()
plt.show()

# %%
# --- Reordered Cluster × Module heatmap with majority-vote annotation ---
import matplotlib.gridspec as gridspec
import matplotlib

cluster_ids = sorted([l for l in np.unique(cp.labels) if l != -1])
modules_list = sorted(set(node_modules) - {'unknown'})
if 'unknown' in set(node_modules):
    modules_list = modules_list + ['unknown']

# Build raw count matrix: rows=clusters, cols=modules
count_matrix = np.zeros((len(cluster_ids), len(modules_list)), dtype=int)
for ci, cl in enumerate(cluster_ids):
    cl_mask = cp.labels == cl
    for mi, mod in enumerate(modules_list):
        count_matrix[ci, mi] = np.sum(cl_mask & (node_modules == mod))

# ICN row
icn_mask = cp.labels == -1
icn_row = np.array([[np.sum(icn_mask & (node_modules == mod)) for mod in modules_list]])

# Majority vote per cluster (index into modules_list)
majority_module_idx = np.argmax(count_matrix, axis=1)
majority_module_name = [modules_list[i] for i in majority_module_idx]

# Sort clusters by majority-module index (stable → clusters with same majority stay together)
sort_order = np.argsort(majority_module_idx, kind='stable')
cluster_ids_sorted = [cluster_ids[i] for i in sort_order]
count_matrix_sorted = count_matrix[sort_order, :]
majority_sorted = [majority_module_name[i] for i in sort_order]

# Reorder columns (modules) in the order they first appear as majority,
# so the dominant block walks diagonally from top-left to bottom-right
seen_mods = []
for m in majority_sorted:
    if m not in seen_mods:
        seen_mods.append(m)
for m in modules_list:          # append any module never a majority
    if m not in seen_mods:
        seen_mods.append(m)
module_order = seen_mods

col_idx = [modules_list.index(m) for m in module_order]
count_matrix_reordered = count_matrix_sorted[:, col_idx]
icn_row_reordered = icn_row[:, col_idx]

# Stack ICN row at bottom
full_matrix = np.vstack([count_matrix_reordered, icn_row_reordered])
row_labels_heat = [f'C{cl}' for cl in cluster_ids_sorted] + ['ICN']
majority_col = majority_sorted + ['—']

# Row-normalize (fraction of each cluster's cells in each module)
row_sums = full_matrix.sum(axis=1, keepdims=True)
matrix_norm = np.where(row_sums > 0, full_matrix / row_sums, 0.0)

# Colour palette for majority-vote annotation
unique_mods_ordered = list(dict.fromkeys(majority_sorted))
cmap_qual = matplotlib.colormaps.get_cmap('tab20').resampled(max(len(unique_mods_ordered), 1))
mod_color = {m: cmap_qual(i) for i, m in enumerate(unique_mods_ordered)}
mod_color['—'] = (0.85, 0.85, 0.85, 1.0)

n_rows = len(row_labels_heat)
n_cols = len(module_order)

fig = plt.figure(figsize=(max(10, n_cols * 0.55 + 4), max(8, n_rows * 0.22 + 2)))
# Three panels: majority-vote labels | colour bar | heatmap
gs = gridspec.GridSpec(1, 3, width_ratios=[2.2, 0.25, max(n_cols * 0.55, 5)], wspace=0.03)

# ── Left panel: majority-vote text ──────────────────────────────────────────
ax_txt = fig.add_subplot(gs[0])
ax_txt.set_xlim(0, 1)
ax_txt.set_ylim(-0.5, n_rows - 0.5)
ax_txt.invert_yaxis()
ax_txt.axis('off')
ax_txt.set_title('Majority\nModule', fontsize=8, pad=4)
for ri, mod in enumerate(majority_col):
    color = mod_color[mod]
    ax_txt.text(
        0.97, ri, mod, ha='right', va='center', fontsize=7,
        bbox=dict(boxstyle='round,pad=0.2', facecolor=color, alpha=0.75, edgecolor='none'),
    )

# ── Middle panel: solid colour bar ──────────────────────────────────────────
ax_bar = fig.add_subplot(gs[1])
bar_img = np.array([mod_color[m] for m in majority_col]).reshape(n_rows, 1, 4)
ax_bar.imshow(bar_img, aspect='auto', interpolation='nearest')
ax_bar.set_xticks([])
ax_bar.set_yticks([])

# ── Right panel: heatmap ─────────────────────────────────────────────────────
ax_heat = fig.add_subplot(gs[2])
im = ax_heat.imshow(matrix_norm, aspect='auto', cmap='Blues', vmin=0, vmax=1)

ax_heat.set_xticks(range(n_cols))
ax_heat.set_xticklabels(module_order, rotation=45, ha='right', fontsize=8)
ax_heat.set_yticks(range(n_rows))
ax_heat.set_yticklabels(row_labels_heat, fontsize=7)

# Dashed separator above ICN row
ax_heat.axhline(n_rows - 1.5, color='red', linewidth=1.2, linestyle='--')

ax_heat.set_xlabel('RTL Module', fontsize=10)
ax_heat.set_title(f'{DESIGN} — Cluster × Module (reordered for diagonal)', fontsize=10)
plt.colorbar(im, ax=ax_heat, label='Fraction of cluster cells', shrink=0.8, pad=0.02)

fig.subplots_adjust(left=0.18, right=0.92, top=0.93, bottom=0.22)
plt.show()

# %%
# --- Normalized Mutual Information: clustering vs module assignment ---
# Only use non-ICN cells that have a known module
non_icn = cp.labels != -1
known   = node_modules != 'unknown'
mask    = non_icn & known

cluster_labels_masked = cp.labels[mask]
module_labels_masked  = node_modules[mask]

nmi = normalized_mutual_info_score(module_labels_masked, cluster_labels_masked, average_method='arithmetic')
print(f"NMI (clustering vs module): {nmi:.4f}")
print("  1.0 = clustering perfectly recovers module structure")
print("  0.0 = clustering is independent of module structure")
# Out:
# NMI (clustering vs module): 1.0000
#   1.0 = clustering perfectly recovers module structure
#   0.0 = clustering is independent of module structure
